# %%
import pandas as pd

df = pd.read_csv('pendapatan_train.csv')
df_test = pd.read_csv('pendapatan_test.csv')

df_full = [df,df_test]
df.head()
# Out:
#    id  Umur             Kelas Pekerja  Berat Akhir Pendidikan  \
# 0   0    40                Wiraswasta       205047        SMA
# 1   1    33          Pemerintah Lokal       298785       10th
# 2   2    26                Wiraswasta       106856         D4
# 3   3    54  Pekerja Bebas Perusahaan       117674    Sarjana
# 4   4    48                Wiraswasta       268234        SMA
#
#    Jmlh Tahun Pendidikan     Status Perkawinan            Pekerjaan  \
# 0                      9           Menikah LDR  Perbaikan Kerajinan
# 1                      6                 Cerai                Supir
# 2                     11  Belum Pernah Menikah         Pemuka Agama
# 3                     13               Menikah                Sales
# 4                      9                 Cerai  Perbaikan Kerajinan
#
#   Jenis Kelamin  Keuntungan Kapital  Kerugian Capital  Jam per Minggu   Gaji
# 0         Laki2                 0.0               0.0            40.0   >7jt
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28794 entries, 0 to 28793
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     28794 non-null  int64
#  1   Umur                   28794 non-null  int64
#  2   Kelas Pekerja          28794 non-null  object
#  3   Berat Akhir            28794 non-null  int64
#  4   Pendidikan             28794 non-null  object
#  5   Jmlh Tahun Pendidikan  28794 non-null  int64
#  6   Status Perkawinan      28794 non-null  object
#  7   Pekerjaan              28794 non-null  object
#  8   Jenis Kelamin          28794 non-null  object
#  9   Keuntungan Kapital     28794 non-null  float64
#  10  Kerugian Capital       28794 non-null  float64
#  11  Jam per Minggu         28794 non-null  float64
#  12  Gaji                   28794 non-null  object
# dtypes: float64(3), int64(4), object(6)
# memory usage: 2.9+ MB

# %%
df.isna().sum(axis=0)
# Out:
# id                       0
# Umur                     0
# Kelas Pekerja            0
# Berat Akhir              0
# Pendidikan               0
# Jmlh Tahun Pendidikan    0
# Status Perkawinan        0
# Pekerjaan                0
# Jenis Kelamin            0
# Keuntungan Kapital       0
# Kerugian Capital         0
# Jam per Minggu           0
# Gaji                     0
# dtype: int64

# %%
df = pd.get_dummies(df,columns=['Kelas Pekerja','Status Perkawinan','Pekerjaan'])
df
# Out:
#           id  Umur  Berat Akhir         Pendidikan  Jmlh Tahun Pendidikan  \
# 0          0    40       205047                SMA                      9
# 1          1    33       298785               10th                      6
# 2          2    26       106856                 D4                     11
# 3          3    54       117674            Sarjana                     13
# 4          4    48       268234                SMA                      9
# ...      ...   ...          ...                ...                    ...
# 28789  28789    41       244945  Pendidikan Tinggi                     10
# 28790  28790    32       242323  Pendidikan Tinggi                     10
# 28791  28791    54       150999  Pendidikan Tinggi                     10
# 28792  28792    44       171615                SMA                      9
# 28793  28793    19       292136  Pendidikan Tinggi                     10
#
#       Jenis Kelamin  Keuntungan Kapital  Kerugian Capital  Jam per Minggu  \
# ...

# %%
gajii = {'>7jt':1,'<=7jt':0}

df['Gaji'] = df['Gaji'].replace(gajii)
df
# Out:
#           id  Umur  Berat Akhir         Pendidikan  Jmlh Tahun Pendidikan  \
# 0          0    40       205047                SMA                      9
# 1          1    33       298785               10th                      6
# 2          2    26       106856                 D4                     11
# 3          3    54       117674            Sarjana                     13
# 4          4    48       268234                SMA                      9
# ...      ...   ...          ...                ...                    ...
# 28789  28789    41       244945  Pendidikan Tinggi                     10
# 28790  28790    32       242323  Pendidikan Tinggi                     10
# 28791  28791    54       150999  Pendidikan Tinggi                     10
# 28792  28792    44       171615                SMA                      9
# 28793  28793    19       292136  Pendidikan Tinggi                     10
#
#       Jenis Kelamin  Keuntungan Kapital  Kerugian Capital  Jam per Minggu  \
# ...

# %% [markdown]
# ## Melihat statistic dari data

# %%
df.describe()
# Out:
#                  id          Umur   Berat Akhir  Jmlh Tahun Pendidikan  \
# count  28794.000000  28794.000000  2.879400e+04           28794.000000
# mean   14396.500000     38.557095  1.897640e+05              10.075919
# std     8312.256162     13.668667  1.047810e+05               2.561954
# min        0.000000     17.000000  1.349200e+04               1.000000
# 25%     7198.250000     28.000000  1.178668e+05               9.000000
# 50%    14396.500000     37.000000  1.785235e+05              10.000000
# 75%    21594.750000     48.000000  2.373860e+05              12.000000
# max    28793.000000     90.000000  1.490400e+06              16.000000
#
#        Keuntungan Kapital  Kerugian Capital  Jam per Minggu          Gaji  \
# count        2.879400e+04      2.879400e+04    28794.000000  28794.000000
# mean         1.547702e+07      1.221002e+06       40.398555      0.236890
# std          1.063346e+08      5.633757e+06       12.371845      0.425181
# ...

# %%
df[['Umur','Jam per Minggu']].hist(figsize=(11,11))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001BB3CEF61F0>,
# ...
#       dtype=object)

# %% [markdown]
# ## Berapa jumlah gaji yang  >7jt dan <=7jt

# %%
df['Gaji'].value_counts()
# Out:
# 0    21973
# 1     6821
# Name: Gaji, dtype: int64

# %%
df.pivot_table(['Gaji'],['Jenis Kelamin']).sort_values(by = ['Gaji'],ascending=False)
# Out:
#                    Gaji
# Jenis Kelamin
# Laki2          0.299578
# Perempuan      0.111689

# %% [markdown]
# Pada Data ini cukup menggambarkan 30% Laki2 yang Gajinya lebih besar dari pada perempuan yang hanya 11%

# %%
df.pivot_table(['Gaji'],['Jenis Kelamin','Pendidikan']).sort_values(by = ['Gaji'],ascending=False)
# Out:
#                                         Gaji
# Jenis Kelamin Pendidikan
# Laki2         Sekolah Professional  0.795181
#               Doktor                0.772109
#               Master                0.630859
# Perempuan     Doktor                0.611111
# Laki2         Sarjana               0.498167
# Perempuan     Sekolah Professional  0.456790
#               Master                0.359756
# Laki2         D3                    0.356115
#               D4                    0.330368
#               Pendidikan Tinggi     0.252661
# Perempuan     Sarjana               0.228727
# Laki2         SMA                   0.199525
# Perempuan     D3                    0.136364
#               D4                    0.129252
# Laki2         12th                  0.090909
#               7th-8th               0.086294
#               10th                  0.085066
#               9th                   0.079511
#               11th                  0.070504
# ...

# %% [markdown]
# Pada Data ini cukup menggambarkan pada Laki2 yang menempuh pendidikan SMA mempunyai persentase 80%,Laki2 yang menempuh pendidikan Doktor mempunyai persentase 77%,Laki2 yang menempuh pendidikan Master mempunyai persentase 63%, dan Perempuan yang menempuh pendidikan Doktor mempunyai persentase 61% lebih banyak peluang dengaji gaji >7jt dan <=7jt. Dibandingkan pada pada Laki2 dan perempuan yang menempuh pendidikan dari 12th hingga SD lebih sedidikit peluang dengaji gaji >7jt dan <=7jt.
#
# Bisa kita liat visualisai dibawah ini yang mengambarkan dari suatu data di atas.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns 
sns.set()

# %%
test_sex = {'Perempuan':0,'Laki2':1}
df['Jenis Kelamin'] = df['Jenis Kelamin'].replace(test_sex)

# %%
# Visualisasi data
with sns.axes_style(style='ticks'):
    g = sns.catplot('Pendidikan','Gaji',kind="bar",hue='Jenis Kelamin',aspect=3.6,data=df)

# %%
df.pivot_table(['Gaji'],['Pendidikan']).sort_values(by = ['Gaji'],ascending=False)
# Out:
#                           Gaji
# Pendidikan
# Doktor                0.747126
# Sekolah Professional  0.739919
# Master                0.542876
# Sarjana               0.414716
# D3                    0.264706
# D4                    0.258143
# Pendidikan Tinggi     0.181903
# SMA                   0.154915
# 12th                  0.072000
# 7th-8th               0.064935
# 9th                   0.063181
# 10th                  0.059611
# 5th-6th               0.059211
# 11th                  0.053622
# 1st-4th               0.040816
# SD                    0.000000

# %% [markdown]
# Pada Data ini cukup menggambarkan pendidikan sangat berpengaruh terhadap gaji. Dimana Doktor yang mempunyai persentase 74%, Sekolah Propesional yang mempunyai persentase 73%,Master yang mempunyai persentase 54%,Sarjana yang mempunyai persentase 41% lebih banyak peluang dengaji gaji >7jt dan <=7jt.

# %%
# Visualisasi data
with sns.axes_style(style='ticks'):
    g = sns.catplot('Pendidikan','Jmlh Tahun Pendidikan',kind="bar",hue='Gaji',aspect=3.6,data=df)

# %% [markdown]
# Pada visualisasi tersebut kita dapat melihat pada data bawha pendidikan dan jumlah tahun pendidikan sangat berpengaruh terhadap gaji. Dimana yang jumlah tahun pendidikan lebih dari 10 tahun dan menempuh pendidikan D4,D3,Sarjana,Sekolah Propesional,Master dan Doktor lebih banyak peluang dengaji gaji >7jt dan <=7jt. Dari pada yang jumlah tahun pendidikan kurang dari 10 tidak banyak peluang dengaji gaji >7jt dan <=7jt.

# %%
df_test = pd.get_dummies(df_test,columns=['Kelas Pekerja','Status Perkawinan','Pekerjaan'])
test_sex = {'Perempuan':0,'Laki2':1}
Kelas_test_pendidikan = {'SD' : 0,'1st-4th': 1,'5th-6th': 2,'7th-8th': 3 ,'9th': 4, '10th': 5, '11th': 6,'12th': 7,
                   'Pendidikan Tinggi': 8,'SMA': 9,'Sekolah Professional': 10,'D4': 11,'D3': 12,'Sarjana': 13,
                   'Sarjana': 13,'Master': 14,'Doktor': 15}

df_test['Jenis Kelamin'] = df_test['Jenis Kelamin'].replace(test_sex)
df_test['Pendidikan'] = df_test['Pendidikan'].replace(Kelas_test_pendidikan)
df_test
# Out:
#          id  Umur  Berat Akhir  Pendidikan  Jmlh Tahun Pendidikan  \
# 0     28794    31       207301           9                      9
# 1     28795    34       324254           9                      9
# 2     28796    58        27385           9                      9
# 3     28797    49       723746           9                      9
# 4     28798    60       194980           9                      9
# ...     ...   ...          ...         ...                    ...
# 9594  38388    54       297551           8                     10
# 9595  38389    33       236396          13                     13
# 9596  38390    24        83774           9                      9
# 9597  38391    34       340458           9                      9
# 9598  38392    63       209790           9                      9
#
#       Jenis Kelamin  Keuntungan Kapital  Kerugian Capital  Jam per Minggu  \
# 0                 0                 0.0               0.0            40.0
# ...

# %%
df_test= df_test.drop(['Keuntungan Kapital','Kerugian Capital','Berat Akhir'],axis=1)
df_test
# Out:
#          id  Umur  Pendidikan  Jmlh Tahun Pendidikan  Jenis Kelamin  \
# 0     28794    31           9                      9              0
# 1     28795    34           9                      9              1
# 2     28796    58           9                      9              1
# 3     28797    49           9                      9              1
# 4     28798    60           9                      9              0
# ...     ...   ...         ...                    ...            ...
# 9594  38388    54           8                     10              1
# 9595  38389    33          13                     13              1
# 9596  38390    24           9                      9              1
# 9597  38391    34           9                      9              0
# 9598  38392    63           9                      9              1
#
#       Jam per Minggu  Kelas Pekerja_?  \
# 0               40.0                0
# 1               40.0                0
# ...

# %%
Kelas_pendidikan = {'SD' : 0,'1st-4th': 1,'5th-6th': 2,'7th-8th': 3 ,'9th': 4, '10th': 5, '11th': 6,'12th': 7,
                   'Pendidikan Tinggi': 8,'SMA': 9,'Sekolah Professional': 10,'D4': 11,'D3': 12,'Sarjana': 13,
                   'Sarjana': 13,'Master': 14,'Doktor': 15}
df['Pendidikan'] = df['Pendidikan'].replace(Kelas_pendidikan)

# %%
df= df.drop(['Keuntungan Kapital','Kerugian Capital','Berat Akhir'],axis=1)
df
# Out:
#           id  Umur  Pendidikan  Jmlh Tahun Pendidikan  Jenis Kelamin  \
# 0          0    40           9                      9              1
# 1          1    33           5                      6              1
# 2          2    26          11                     11              0
# 3          3    54          13                     13              1
# 4          4    48           9                      9              1
# ...      ...   ...         ...                    ...            ...
# 28789  28789    41           8                     10              1
# 28790  28790    32           8                     10              0
# 28791  28791    54           8                     10              1
# 28792  28792    44           9                      9              1
# 28793  28793    19           8                     10              0
#
#        Jam per Minggu  Gaji  Kelas Pekerja_?  \
# 0                40.0     1                0
# ...

# %%
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, log_loss
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.model_selection import train_test_split
# sss = StratifiedShuffleSplit(n_splits=10, test_size=0.1, random_state=0)
X = df.drop('Gaji',axis=1)
y = df['Gaji']

acc_dict = {}

# for train_index, test_index in sss.split(X, y):
# 	X_train, X_test = X[train_index], X[test_index]
# 	y_train, y_test = y[train_index], y[test_index]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
y_train
# Out:
# 5365     0
# 27632    0
# 12143    0
# 27353    1
# 17361    0
#         ..
# 13123    0
# 19648    0
# 9845     0
# 10799    1
# 2732     0
# Name: Gaji, Length: 23035, dtype: int64

# %%
classifiers = [
    KNeighborsClassifier(3),
    SVC(probability=True),
    DecisionTreeClassifier(),
    RandomForestClassifier(),
	  AdaBoostClassifier(),
    GradientBoostingClassifier(),
    GaussianNB(),
    LinearDiscriminantAnalysis(),
    QuadraticDiscriminantAnalysis(),
    LogisticRegression()]

log_cols = ["Classifier", "Accuracy"]
log= pd.DataFrame(columns=log_cols)

for clf in classifiers:
	name = clf.__class__.__name__
	clf.fit(X_train, y_train)
	train_predictions = clf.predict(X_test)
	acc = accuracy_score(y_test, train_predictions)
	if name in acc_dict:
		acc_dict[name] += acc
	else:
		acc_dict[name] = acc

for clf in acc_dict:
	acc_dict[clf] = acc_dict[clf]
	log_entry = pd.DataFrame([[clf, acc_dict[clf]]], columns=log_cols)
	log = log.append(log_entry)

plt.xlabel('Accuracy')
plt.title('Classifier Accuracy')

sns.set_color_codes("muted")
sns.barplot(x='Accuracy', y='Classifier', data=log, color="b")
# Out:
# D:\Anaconda\lib\site-packages\sklearn\discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")

# %%
import numpy as np
np.isnan(df.any())
# Out:
# id                                             False
# Umur                                           False
# Pendidikan                                     False
# Jmlh Tahun Pendidikan                          False
# Jenis Kelamin                                  False
# Jam per Minggu                                 False
# Gaji                                           False
# Kelas Pekerja_?                                False
# Kelas Pekerja_Pekerja Bebas Bukan Perusahan    False
# Kelas Pekerja_Pekerja Bebas Perusahaan         False
# Kelas Pekerja_Pemerintah Lokal                 False
# Kelas Pekerja_Pemerintah Negara                False
# Kelas Pekerja_Pemerintah Provinsi              False
# Kelas Pekerja_Tanpa di Bayar                   False
# Kelas Pekerja_Tidak Pernah Bekerja             False
# Kelas Pekerja_Wiraswasta                       False
# Status Perkawinan_Belum Pernah Menikah         False
# Status Perkawinan_Berpisah                     False
# ...

# %%
GBC = GradientBoostingClassifier(loss='exponential',learning_rate=0.2,n_estimators=1200,max_depth= 3,
                                 validation_fraction=1)
GBC.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.2, loss='exponential',
#                            n_estimators=1200, validation_fraction=1)

# %%
GBC.score(X_train, y_train)
# Out:
# 0.8912090297373562

# %%
GBC.estimators_
# Out:
# array([[DecisionTreeRegressor(criterion='friedman_mse', max_depth=5,
#                       random_state=RandomState(MT19937) at 0x1BB39233540)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=5,
#                       random_state=RandomState(MT19937) at 0x1BB39233540)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=5,
#                       random_state=RandomState(MT19937) at 0x1BB39233540)],
#        ...,
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=5,
#                       random_state=RandomState(MT19937) at 0x1BB39233540)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=5,
#                       random_state=RandomState(MT19937) at 0x1BB39233540)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=5,
#                       random_state=RandomState(MT19937) at 0x1BB39233540)]],
#       dtype=object)

# %%
from sklearn.model_selection import cross_validate

cv_score = cross_validate(GBC,X,y,cv= 10,scoring='roc_auc',return_train_score=True)
cv_score

# %%
df_test = df_test.drop('prediction',axis=1)

# %%
y_pred = GBC.predict(df_test)
y_pred

# %%
df_test['prediction'] = y_pred
df_test['prediction']

# %%
df_test_1 = pd.read_csv('pendapatan_test.csv')
df_test_1
# Out:
#          id  Umur        Kelas Pekerja  Berat Akhir         Pendidikan  \
# 0     28794    31  Pemerintah Provinsi       207301                SMA
# 1     28795    34           Wiraswasta       324254                SMA
# 2     28796    58           Wiraswasta        27385                SMA
# 3     28797    49           Wiraswasta       723746                SMA
# 4     28798    60           Wiraswasta       194980                SMA
# ...     ...   ...                  ...          ...                ...
# 9594  38388    54           Wiraswasta       297551  Pendidikan Tinggi
# 9595  38389    33           Wiraswasta       236396            Sarjana
# 9596  38390    24           Wiraswasta        83774                SMA
# 9597  38391    34           Wiraswasta       340458                SMA
# 9598  38392    63           Wiraswasta       209790                SMA
#
#       Jmlh Tahun Pendidikan Status Perkawinan              Pekerjaan  \
# ...

# %%
submission = pd.DataFrame(df_test_1['id'])
submission
# Out:
#          id
# 0     28794
# 1     28795
# 2     28796
# 3     28797
# 4     28798
# ...     ...
# 9594  38388
# 9595  38389
# 9596  38390
# 9597  38391
# 9598  38392
#
# [9599 rows x 1 columns]

# %%
submission['Gaji'] = df_test['prediction']
submission
# Out:
#          id  Gaji
# 0     28794     1
# 1     28795     0
# 2     28796     1
# 3     28797     1
# 4     28798     0
# ...     ...   ...
# 9594  38388     1
# 9595  38389     1
# 9596  38390     0
# 9597  38391     0
# 9598  38392     0
#
# [9599 rows x 2 columns]

# %%
submission['Gaji'].iloc[0:50]
# Out:
# 0     1
# 1     0
# 2     1
# 3     1
# 4     0
# 5     0
# 6     0
# 7     0
# 8     1
# 9     0
# 10    0
# 11    0
# 12    0
# 13    0
# 14    0
# 15    1
# 16    0
# 17    0
# 18    0
# 19    0
# 20    1
# 21    0
# 22    1
# 23    1
# 24    0
# 25    1
# 26    0
# 27    0
# 28    0
# 29    0
# 30    0
# 31    0
# 32    0
# 33    0
# 34    0
# 35    0
# 36    0
# 37    0
# 38    1
# 39    0
# 40    0
# 41    0
# 42    1
# 43    0
# 44    0
# 45    0
# 46    0
# 47    0
# 48    0
# 49    0
# Name: Gaji, dtype: int64

# %%
submission.to_csv('SubmissionSanbercode.csv', index=False)

# %%
submission_df = pd.read_csv("SubmissionSanbercode.csv")
submission_df
# Out:
#          id  Gaji
# 0     28794     1
# 1     28795     0
# 2     28796     1
# 3     28797     1
# 4     28798     0
# ...     ...   ...
# 9594  38388     1
# 9595  38389     1
# 9596  38390     0
# 9597  38391     0
# 9598  38392     0
#
# [9599 rows x 2 columns]
